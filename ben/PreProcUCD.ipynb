# %%
import numpy as np
import pandas as pd
from sklearn import preprocessing
import re

from pandarallel import pandarallel
pandarallel.initialize(progress_bar=False)
# Out:
# INFO: Pandarallel will run on 72 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.

# %%
# I converted everything to parquet because I had tried it for the preprocessed data and it was really fast to load.
# It's still fairly slow for reading the raw, unprocessed data though :(
# You can change back to csv if you like, but I think the parquet is at least slightly faster.
used_car_data = pd.read_parquet('used_cars_data.parquet')

# %%
used_car_data.columns
# Out:
# Index(['vin', 'back_legroom', 'bed', 'bed_height', 'bed_length', 'body_type',
#        'cabin', 'city', 'city_fuel_economy', 'combine_fuel_economy',
#        'daysonmarket', 'dealer_zip', 'description', 'engine_cylinders',
#        'engine_displacement', 'engine_type', 'exterior_color', 'fleet',
#        'frame_damaged', 'franchise_dealer', 'franchise_make', 'front_legroom',
#        'fuel_tank_volume', 'fuel_type', 'has_accidents', 'height',
#        'highway_fuel_economy', 'horsepower', 'interior_color', 'isCab',
#        'is_certified', 'is_cpo', 'is_new', 'is_oemcpo', 'latitude', 'length',
#        'listed_date', 'listing_color', 'listing_id', 'longitude',
#        'main_picture_url', 'major_options', 'make_name', 'maximum_seating',
#        'mileage', 'model_name', 'owner_count', 'power', 'price', 'salvage',
#        'savings_amount', 'seller_rating', 'sp_id', 'sp_name', 'theft_title',
#        'torque', 'transmission', 'transmission_display', 'trimId', 'trim_name',
#        'vehicle_damage_category', 'wheel_system', 'wheel_system_display',
#        'wheelbase', 'width', 'year'],
#       dtype='object')

# %%
used_car_data.loc[used_car_data.back_legroom == '--', 'back_legroom'] = float('nan')

# %%
used_car_data.back_legroom.dropna().str.endswith(' in').all()
# Out:
# True

# %%
used_car_data.back_legroom = used_car_data.back_legroom.str.replace(' in', '').astype('float')

# %%
used_car_data.loc[used_car_data.bed_height == '--', 'bed_height'] = float('nan')

# %%
used_car_data.bed_height.dropna()
# Out:
# Series([], Name: bed_height, dtype: object)

# %%
used_car_data.loc[used_car_data.bed_length == '--', 'bed_length'] = float('nan')

# %%
used_car_data.bed_length.dropna().str.endswith(' in').all()
# Out:
# True

# %%
used_car_data.bed_length = used_car_data.bed_length.str.replace(' in', '').astype('float')

# %%
used_car_data.body_type.unique()
# Out:
# array(['SUV / Crossover', 'Sedan', 'Coupe', 'Hatchback', 'Pickup Truck',
#        'Wagon', 'Minivan', 'Van', 'Convertible', None], dtype=object)

# %%
used_car_data.cabin.unique()
# Out:
# array([None, 'Crew Cab', 'Extended Cab', 'Regular Cab', 'Large Crew Cab'],
#       dtype=object)

# %%
city_vc = used_car_data.city.value_counts()
# top_cities = city_vc[city_vc>5000].index
# DC->Alexandria
top_cities = np.array(['New York', 'Los Angeles', 'Chicago', 'Houston', 'Phoenix', 'Philadelphia', 'San Antonio', 'San Diego', 'Dallas', 'San Jose', 'Austin', 'Jacksonville', 'Fort Worth', 'Columbus', 'Indianapolis', 'Charlotte', 'San Francisco', 'Seattle', 'Denver', 'Oklahoma City', 'Nashville', 'El Paso', 'Alexandria', 'Boston', 'Las Vegas', 'Portland', 'Detroit', 'Louisville', 'Memphis', 'Baltimore', 'Milwaukee', 'Albuquerque', 'Fresno', 'Tucson', 'Sacramento', 'Mesa', 'Kansas City', 'Atlanta', 'Omaha', 'Colorado Springs', 'Raleigh', 'Virginia Beach', 'Long Beach', 'Miami', 'Oakland', 'Minneapolis', 'Tulsa', 'Bakersfield', 'Wichita', 'Arlington'])

# %%
city_data = []
for city in top_cities:
    entries = used_car_data[used_car_data.city==city]
    #print(len(entries))
    city_data += [[entries.latitude.median(), entries.longitude.median()]]
city_data = pd.DataFrame(city_data, columns=['latitude', 'longitude'], index=top_cities)

# %%
((city_data.latitude-32)**2+(city_data.longitude+96)**2).idxmin()
# Out:
# 'Dallas'

# %%
top_city_set = set(top_cities)

# %%
mapped_cities = used_car_data.parallel_apply(lambda x: x.city if x.city in top_city_set else ((city_data.latitude-x.latitude)**2+(city_data.longitude-x.longitude)**2).idxmin(), axis=1)

# %%
mapped_cities
# Out:
# 0            Miami
# 1            Miami
# 2            Miami
# 3            Miami
# 4            Miami
#             ...
# 3000035    Oakland
# 3000036    Oakland
# 3000037    Oakland
# 3000038    Oakland
# 3000039    Oakland
# Length: 3000040, dtype: object

# %%
mapped_cities.value_counts()
# Out:
# New York            156744
# Chicago             140151
# Atlanta             136539
# Jacksonville        136091
# Detroit             123342
# Houston             122767
# Columbus            121324
# Memphis             120543
# Miami               108595
# Boston              104694
# Charlotte           102595
# Alexandria          102269
# Minneapolis          91848
# Philadelphia         85833
# Long Beach           76519
# Dallas               75857
# Milwaukee            69574
# Denver               69007
# Baltimore            67635
# Raleigh              62167
# Las Vegas            61473
# Los Angeles          57089
# San Antonio          56557
# Indianapolis         53984
# Nashville            51978
# Kansas City          51047
# Louisville           47790
# Omaha                47701
# Phoenix              45474
# Sacramento           45421
# San Diego            37269
# San Jose             34701
# Oklahoma City        31615
# Austin               31571
# Tulsa                26020
# Fort Worth           24845
# Portland             21943
# Arlington            21546
# Mesa                 19657
# Virginia Beach       19016
# Oakland              18975
# El Paso              18857
# Seattle              16038
# Albuquerque          15414
# Wichita              13511
# Fresno               12520
# Tucson               12244
# San Francisco        12140
# Colorado Springs     11569
# Bakersfield           7981
# dtype: int64

# %%
used_car_data.city[mapped_cities=='Los Angeles'].value_counts().head(20)
# Out:
# Los Angeles        5790
# Van Nuys           5412
# Valencia           3085
# Glendale           2946
# Thousand Oaks      2639
# Santa Monica       2626
# Oxnard             2513
# Victorville        2288
# Alhambra           2082
# Ventura            2052
# North Hollywood    1680
# Pasadena           1607
# Mission Hills      1553
# El Monte           1336
# Beverly Hills      1166
# Woodland Hills     1124
# Culver City        1068
# Hawthorne           955
# Inglewood           900
# Duarte              794
# Name: city, dtype: int64

# %%
used_car_data.city = mapped_cities

# %%
used_car_data.city_fuel_economy
# Out:
# 0           NaN
# 1           NaN
# 2          17.0
# 3           NaN
# 4           NaN
#            ...
# 3000035    26.0
# 3000036    18.0
# 3000037     NaN
# 3000038    30.0
# 3000039    26.0
# Name: city_fuel_economy, Length: 3000040, dtype: float64

# %%
used_car_data.combine_fuel_economy.dropna()
# Out:
# Series([], Name: combine_fuel_economy, dtype: float64)

# %%
used_car_data.daysonmarket
# Out:
# 0           522
# 1           207
# 2          1233
# 3           196
# 4           137
#            ...
# 3000035      16
# 3000036     171
# 3000037      91
# 3000038      11
# 3000039      17
# Name: daysonmarket, Length: 3000040, dtype: int64

# %%
used_car_data.engine_cylinders = used_car_data.engine_cylinders.str[:2]

# %%
used_car_data.engine_cylinders.value_counts()
# Out:
# I4    1507448
# V6     818732
# V8     386953
# H4      65955
# I3      54304
# I6      51776
# I5       5446
# H6       4686
# V1       2611
# I2        897
# W1        583
# R2         65
# W8          3
# Name: engine_cylinders, dtype: int64

# %%
used_car_data[used_car_data.body_type.isna()]
# Out:
#                        vin  back_legroom   bed bed_height  bed_length  \
# 851      5XXG14J28MG001288           NaN  None       None         NaN
# 857      5XXG14J2XMG006458           NaN  None       None         NaN
# 865      5XXG14J28MG006443           NaN  None       None         NaN
# 896      5XXG14J22MG003974           NaN  None       None         NaN
# 1079     5XXG64J29MG017274           NaN  None       None         NaN
# ...                    ...           ...   ...        ...         ...
# 2998327  3MVDMABL4MM201291           NaN  None       None         NaN
# 2998625  3MVDMBCL5MM202079           NaN  None       None         NaN
# 2999182  JA4AT4AA0KZ050139           NaN  None       None         NaN
# 2999350  1FDRU6ZG5LKA46426           NaN  None       None         NaN
# 2999797  JA4AT4AA9KZ049636           NaN  None       None         NaN
#
#         body_type cabin           city  city_fuel_economy  \
# 851          None  None       New York                NaN
# 857          None  None       New York                NaN
# 865          None  None       New York                NaN
# 896          None  None       New York                NaN
# 1079         None  None       New York                NaN
# ...           ...   ...            ...                ...
# 2998327      None  None     Sacramento                NaN
# 2998625      None  None     Sacramento                NaN
# 2999182      None  None  San Francisco                NaN
# 2999350      None  None     Sacramento                NaN
# 2999797      None  None  San Francisco                NaN
#
#          combine_fuel_economy  ...  transmission  \
# 851                       NaN  ...             A
# 857                       NaN  ...             A
# 865                       NaN  ...             A
# 896                       NaN  ...             A
# 1079                      NaN  ...             A
# ...                       ...  ...           ...
# 2998327                   NaN  ...          None
# 2998625                   NaN  ...          None
# 2999182                   NaN  ...           CVT
# 2999350                   NaN  ...          None
# 2999797                   NaN  ...           CVT
#
#                        transmission_display trimId trim_name  \
# 851                       8-Speed Automatic   None      None
# 857                       8-Speed Automatic   None      None
# 865                       8-Speed Automatic   None      None
# 896                       8-Speed Automatic   None      None
# 1079                      8-Speed Automatic   None      None
# ...                                     ...    ...       ...
# 2998327                                None   None      None
# 2998625                                None   None      None
# 2999182  Continuously Variable Transmission   None      None
# 2999350                                None   None      None
# 2999797  Continuously Variable Transmission   None      None
#
#          vehicle_damage_category wheel_system wheel_system_display wheelbase  \
# 851                          NaN         None                 None      None
# 857                          NaN         None                 None      None
# 865                          NaN         None                 None      None
# 896                          NaN         None                 None      None
# 1079                         NaN         None                 None      None
# ...                          ...          ...                  ...       ...
# 2998327                      NaN         None                 None      None
# 2998625                      NaN         None                 None      None
# 2999182                      NaN         None                 None      None
# 2999350                      NaN         None                 None      None
# 2999797                      NaN         None                 None      None
#
#         width  year
# 851      None  2021
# 857      None  2021
# 865      None  2021
# 896      None  2021
# 1079     None  2021
# ...       ...   ...
# 2998327  None  2021
# 2998625  None  2021
# 2999182  None  2019
# 2999350  None  2020
# 2999797  None  2019
#
# [13543 rows x 66 columns]

# %%
mode_cyl_by_body = used_car_data.groupby('body_type').engine_cylinders.agg(pd.Series.mode)
na_cyl = used_car_data.engine_cylinders.isna() & ~used_car_data.body_type.isna()
used_car_data.loc[na_cyl, 'engine_cylinders'] = mode_cyl_by_body[used_car_data[na_cyl].body_type].values

# %%
mode_cyl_by_mk = used_car_data.groupby('make_name').engine_cylinders.agg(pd.Series.mode)
na_cyl = used_car_data.engine_cylinders.isna()
used_car_data.loc[na_cyl, 'engine_cylinders'] = mode_cyl_by_mk[used_car_data[na_cyl].make_name].values

# %%
used_car_data.engine_cylinders = used_car_data.engine_cylinders.apply(lambda x: 'I4' if not len(x) else x)

# %%
cylinder_config = used_car_data.engine_cylinders.str[0]

# %%
num_cylinders = used_car_data.engine_cylinders.str[1:].astype(int)

# %%
used_car_data['cylinder_config'] = cylinder_config

# %%
used_car_data['num_cylinders'] = num_cylinders

# %%
mode_body_by_mk = used_car_data.groupby('make_name').body_type.agg(pd.Series.mode)
na_body = used_car_data.body_type.isna()
used_car_data.loc[na_body, 'body_type'] = mode_body_by_mk[used_car_data[na_body].make_name].values

# %%
old_car_body_map = {'Kaiser': 'Sedan', 'Hudson': 'Coupe', 'Edsel': 'Wagon', 'DeSoto': 'Coupe', 'Nash': 'Convertible', 'Jensen': 'Coupe'}

# %%
bad_old_cars = used_car_data.body_type.apply(lambda x: not len(x))

# %%
used_car_data.loc[bad_old_cars, 'body_type'] = used_car_data[bad_old_cars].make_name.apply(old_car_body_map.get)

# %%
used_car_data.body_type.value_counts()
# Out:
# SUV / Crossover    1427711
# Sedan               743990
# Pickup Truck        474789
# Hatchback            88387
# Minivan              79806
# Coupe                71643
# Van                  47166
# Wagon                40506
# Convertible          26042
# Name: body_type, dtype: int64

# %%
used_car_data.wheel_system.value_counts()
# Out:
# FWD    1261367
# AWD     695731
# 4WD     584524
# RWD     190757
# 4X2     120929
# Name: wheel_system, dtype: int64

# %%
used_car_data.groupby('wheel_system').body_type.value_counts()
# Out:
# wheel_system  body_type
# 4WD           Pickup Truck       335895
#               SUV / Crossover    247670
#               Van                   954
#               Convertible             2
#               Wagon                   2
#               Coupe                   1
# 4X2           Pickup Truck        84930
#               SUV / Crossover     33078
#               Van                  2921
# AWD           SUV / Crossover    562402
#               Sedan               93373
#               Wagon               15935
#               Coupe                8610
#               Hatchback            7002
#               Pickup Truck         3598
#               Convertible          2622
#               Minivan              1538
#               Van                   651
# FWD           Sedan              557130
#               SUV / Crossover    497891
#               Minivan             76887
#               Hatchback           76872
#               Wagon               21443
#               Van                 17347
#               Coupe               10765
#               Convertible          2771
#               Pickup Truck          261
# RWD           Sedan               67451
#               Coupe               46134
#               SUV / Crossover     28639
#               Van                 20487
#               Convertible         19993
#               Pickup Truck         5839
#               Wagon                1581
#               Hatchback             601
#               Minivan                32
# Name: body_type, dtype: int64

# %%
used_car_data[used_car_data.body_type == 'SUV / Crossover'].groupby('wheel_system').price.mean()
# Out:
# wheel_system
# 4WD    35695.731996
# 4X2    42099.295170
# AWD    32270.872053
# FWD    24759.062040
# RWD    36806.219749
# Name: price, dtype: float64

# %%
used_car_data[used_car_data.body_type == 'Convertible'].groupby('wheel_system').price.median()
# Out:
# wheel_system
# 4WD    46987.5
# AWD    65167.5
# FWD     9995.0
# RWD    29891.0
# Name: price, dtype: float64

# %%
used_car_data.wheel_system.value_counts()
# Out:
# FWD    1261367
# AWD     695731
# 4WD     584524
# RWD     190757
# 4X2     120929
# Name: wheel_system, dtype: int64

# %%
mode_ws_by_body = used_car_data.groupby('body_type').wheel_system.agg(pd.Series.mode)
na_ws = used_car_data.wheel_system.isna()
used_car_data.loc[na_ws, 'wheel_system'] = mode_ws_by_body[used_car_data[na_ws].body_type].values

# %%
front_ctrl = used_car_data.wheel_system.isin({'FWD', '4WD', 'AWD'})
rear_ctrl = used_car_data.wheel_system.isin({'RWD', '4X2', '4WD', 'AWD'}) # Assume 4X2 means RWD

# %%
used_car_data['front_ctrl'] = front_ctrl
used_car_data['rear_ctrl'] = rear_ctrl

# %%
used_car_data[used_car_data.franchise_make.isna()].make_name
# Out:
# 220                  BMW
# 221                  BMW
# 223           Land Rover
# 225              Porsche
# 228        Mercedes-Benz
#                ...
# 3000021              BMW
# 3000030             Ford
# 3000033           Toyota
# 3000035        Chevrolet
# 3000038           Jaguar
# Name: make_name, Length: 572635, dtype: object

# %%
used_car_data.make_name.value_counts()
# Out:
# Ford         476336
# Chevrolet    376892
# Toyota       239128
# Nissan       217896
# Honda        214459
#               ...
# Austin            1
# Hillman           1
# Edsel             1
# Pagani            1
# Rover             1
# Name: make_name, Length: 100, dtype: int64

# %%
all_fms = set(used_car_data.franchise_make.values)

# %%
can_use_make = used_car_data.franchise_make.isna() & used_car_data.make_name.isin(all_fms)
used_car_data.loc[can_use_make, 'franchise_make'] = used_car_data[can_use_make].make_name

# %%
top50_makes = set(used_car_data.make_name.value_counts().head(50).index)

# %%
used_car_data.loc[used_car_data.make_name.isin(top50_makes), 'common_make'] = used_car_data[used_car_data.make_name.isin(top50_makes)].make_name

# %%
used_car_data[used_car_data.common_make.isna()]
# Out:
#                        vin  back_legroom   bed bed_height  bed_length  \
# 3031     YH4K14AA1CA001652          31.4  None       None         NaN
# 11304    SCCPC11105HL30473           NaN  None       None         NaN
# 17094    XL9AABAG3AZ363244           NaN  None       None         NaN
# 24250             K1177021           NaN  None       None         NaN
# 37549    WDBVF79J67A001813          40.3  None       None         NaN
# ...                    ...           ...   ...        ...         ...
# 2972191  SCCLMDDC7LHA10495           NaN  None       None         NaN
# 2985683  SCCPC11115HL34273           NaN  None       None         NaN
# 2986446  000000000PXEB1284           NaN  None       None         NaN
# 2990382  WDYPE8DC4E5888494           NaN  None       None         NaN
# 2991691  YH4K14AA4CA001077          31.4  None       None         NaN
#
#            body_type cabin           city  city_fuel_economy  \
# 3031           Sedan  None       New York               20.0
# 11304    Convertible  None       New York               20.0
# 17094    Convertible  None       New York                NaN
# 24250          Sedan  None        Detroit                NaN
# 37549          Sedan  None       New York               10.0
# ...              ...   ...            ...                ...
# 2972191        Coupe  None        Oakland               17.0
# 2985683  Convertible  None  San Francisco               20.0
# 2986446        Coupe  None  San Francisco                NaN
# 2990382          Van  None       San Jose                NaN
# 2991691        Sedan  None        Oakland               20.0
#
#          combine_fuel_economy  ...  wheel_system wheel_system_display  \
# 3031                      NaN  ...           RWD     Rear-Wheel Drive
# 11304                     NaN  ...           RWD     Rear-Wheel Drive
# 17094                     NaN  ...           RWD                 None
# 24250                     NaN  ...           FWD                 None
# 37549                     NaN  ...           RWD     Rear-Wheel Drive
# ...                       ...  ...           ...                  ...
# 2972191                   NaN  ...           RWD     Rear-Wheel Drive
# 2985683                   NaN  ...           RWD     Rear-Wheel Drive
# 2986446                   NaN  ...           RWD                 None
# 2990382                   NaN  ...           RWD                 None
# 2991691                   NaN  ...           RWD     Rear-Wheel Drive
#
#         wheelbase    width  year cylinder_config num_cylinders front_ctrl  \
# 3031     124.4 in    84 in  2012               I             4      False
# 11304     90.5 in  72.8 in  2005               I             4      False
# 17094        None     None  2010               I             4      False
# 24250        None     None  1953               I             4       True
# 37549    133.5 in    78 in  2007               V             1      False
# ...           ...      ...   ...             ...           ...        ...
# 2972191  101.4 in  77.6 in  2020               V             6      False
# 2985683   90.5 in  72.8 in  2005               I             4      False
# 2986446      None     None  1960               V             8      False
# 2990382      None     None  2014               V             6      False
# 2991691  124.4 in    84 in  2012               I             4      False
#
#         rear_ctrl  common_make
# 3031         True          NaN
# 11304        True          NaN
# 17094        True          NaN
# 24250       False          NaN
# 37549        True          NaN
# ...           ...          ...
# 2972191      True          NaN
# 2985683      True          NaN
# 2986446      True          NaN
# 2990382      True          NaN
# 2991691      True          NaN
#
# [854 rows x 71 columns]

# %%
used_car_data.engine_displacement
# Out:
# 0          1300.0
# 1          2000.0
# 2          2500.0
# 3          3000.0
# 4          2000.0
#             ...
# 3000035    1500.0
# 3000036    3600.0
# 3000037    2000.0
# 3000038    2000.0
# 3000039    2500.0
# Name: engine_displacement, Length: 3000040, dtype: float64

# %%
used_car_data.frame_damaged = used_car_data.frame_damaged.fillna(False)

# %%
used_car_data.franchise_dealer
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#            ...
# 3000035    False
# 3000036     True
# 3000037     True
# 3000038    False
# 3000039     True
# Name: franchise_dealer, Length: 3000040, dtype: bool

# %%
used_car_data.franchise_make.value_counts()
# Out:
# Ford             477084
# Chevrolet        407525
# Toyota           233284
# Honda            217375
# Jeep             203978
# Nissan           200064
# Hyundai          130170
# Kia              112805
# RAM               88184
# Buick             82680
# GMC               78880
# Volkswagen        77308
# Dodge             74054
# Subaru            73697
# Mercedes-Benz     64268
# BMW               62557
# Mazda             54230
# Cadillac          43513
# Lexus             38716
# Audi              36048
# Acura             32096
# Chrysler          30077
# Lincoln           29912
# INFINITI          26496
# Mitsubishi        24620
# Volvo             23150
# Land Rover        16706
# Porsche           14027
# MINI               8043
# Jaguar             7177
# Scion              5544
# FIAT               5471
# Maserati           3775
# Alfa Romeo         2173
# Genesis            1504
# Bentley            1054
# Ferrari             965
# Rolls-Royce         735
# Aston Martin        653
# Lotus               506
# McLaren             407
# Lamborghini         361
# smart               330
# Freightliner         87
# Shelby               77
# Rover                26
# SRT                  21
# Pagani               13
# Name: franchise_make, dtype: int64

# %%
used_car_data.front_legroom = used_car_data.front_legroom.replace('--', float('nan'))

# %%
used_car_data.front_legroom.dropna().str.endswith(' in').all()
# Out:
# True

# %%
used_car_data.front_legroom = used_car_data.front_legroom.str.replace(' in', '').astype('float')

# %%
used_car_data.fuel_tank_volume = used_car_data.fuel_tank_volume.replace('--', float('nan'))

# %%
used_car_data.fuel_tank_volume.dropna().str.endswith(' gal').all()
# Out:
# True

# %%
used_car_data.fuel_tank_volume = used_car_data.fuel_tank_volume.str.replace(' gal', '').astype('float')

# %%
used_car_data.fuel_type
# Out:
# 0          Gasoline
# 1          Gasoline
# 2          Gasoline
# 3          Gasoline
# 4          Gasoline
#              ...
# 3000035    Gasoline
# 3000036    Gasoline
# 3000037        None
# 3000038      Diesel
# 3000039    Gasoline
# Name: fuel_type, Length: 3000040, dtype: object

# %%
used_car_data.has_accidents = used_car_data.has_accidents.fillna(False)

# %%
used_car_data.height = used_car_data.height.replace('--', float('nan'))
used_car_data.height.str.endswith(' in').all()
# Out:
# True

# %%
used_car_data.height = used_car_data.height.str.replace(' in', '').astype('float')

# %%
used_car_data.fleet = used_car_data.fleet.fillna(False)

# %%
used_car_data.highway_fuel_economy
# Out:
# 0           NaN
# 1           NaN
# 2          23.0
# 3           NaN
# 4           NaN
#            ...
# 3000035    32.0
# 3000036    27.0
# 3000037     NaN
# 3000038    40.0
# 3000039    33.0
# Name: highway_fuel_economy, Length: 3000040, dtype: float64

# %%
used_car_data.horsepower
# Out:
# 0          177.0
# 1          246.0
# 2          305.0
# 3          340.0
# 4          246.0
#            ...
# 3000035    170.0
# 3000036    310.0
# 3000037    240.0
# 3000038    180.0
# 3000039    170.0
# Name: horsepower, Length: 3000040, dtype: float64

# %%
used_car_data.isCab = used_car_data.isCab.fillna(False)

# %%
used_car_data.is_cpo = used_car_data.is_cpo.fillna(False)

# %%
used_car_data.is_new.hasnans
# Out:
# False

# %%
((used_car_data.is_oemcpo.fillna(False) | used_car_data.is_cpo) == used_car_data.is_cpo).all()
# Out:
# True

# %%
used_car_data.length = used_car_data.length.replace('--', float('nan'))
used_car_data.length.str.endswith(' in').all()
# Out:
# True

# %%
used_car_data.length = used_car_data.length.str.replace(' in', '').astype('float')

# %%
month_listed = used_car_data.listed_date.astype('datetime64').dt.month
year_listed = used_car_data.listed_date.astype('datetime64').dt.year

# %%
month_listed.value_counts()
# Out:
# 8     1106388
# 9      565170
# 7      536309
# 6      225923
# 3      115727
# 2       93972
# 5       88574
# 1       69368
# 4       63353
# 12      57037
# 11      44123
# 10      34096
# Name: listed_date, dtype: int64

# %%
used_car_data.maximum_seating = used_car_data.maximum_seating.replace('--', float('nan'))
used_car_data.maximum_seating.str.endswith(' seats').all()
# Out:
# True

# %%
used_car_data.maximum_seating = used_car_data.maximum_seating.str.replace(' seats', '').astype('float')

# %%
used_car_data.mileage
# Out:
# 0              7.0
# 1              8.0
# 2              NaN
# 3             11.0
# 4              7.0
#             ...
# 3000035    41897.0
# 3000036        5.0
# 3000037    57992.0
# 3000038    27857.0
# 3000039    22600.0
# Name: mileage, Length: 3000040, dtype: float64

# %%
used_car_data.owner_count = used_car_data.owner_count.fillna(1.)

# %%
used_car_data.price
# Out:
# 0          23141.0
# 1          46500.0
# 2          46995.0
# 3          67430.0
# 4          48880.0
#             ...
# 3000035    17998.0
# 3000036    36490.0
# 3000037    12990.0
# 3000038    26998.0
# 3000039    19900.0
# Name: price, Length: 3000040, dtype: float64

# %%
used_car_data.seller_rating = used_car_data.seller_rating.fillna(4.)

# %%
used_car_data.sp_name
# Out:
# 0                                          Flagship Chrysler
# 1                                        Land Rover San Juan
# 2                                           FIAT de San Juan
# 3                                        Land Rover San Juan
# 4                                        Land Rover San Juan
#                                  ...
# 3000035    CarMax Fairfield - Now offering Curbside Picku...
# 3000036                                       Team Chevrolet
# 3000037              Hanlees Chrysler Dodge Jeep Ram of Napa
# 3000038    CarMax Fairfield - Now offering Curbside Picku...
# 3000039                                      Napa Nissan Inc
# Name: sp_name, Length: 3000040, dtype: object

# %%
used_car_data.vehicle_damage_category.dropna()
# Out:
# Series([], Name: vehicle_damage_category, dtype: float64)

# %%
used_car_data.wheel_system.value_counts()
# Out:
# FWD    1294209
# AWD     753762
# 4WD     628790
# RWD     202350
# 4X2     120929
# Name: wheel_system, dtype: int64

# %%
used_car_data.width = used_car_data.width.replace('--', float('nan'))
used_car_data.width.str.endswith(' in').all()
# Out:
# True

# %%
used_car_data.width = used_car_data.width.str.replace(' in', '').astype('float')

# %%
used_car_data.year
# Out:
# 0          2019
# 1          2020
# 2          2016
# 3          2020
# 4          2020
#            ...
# 3000035    2018
# 3000036    2020
# 3000037    2016
# 3000038    2017
# 3000039    2017
# Name: year, Length: 3000040, dtype: int64

# %%
model_age = year_listed - used_car_data.year

# %%
used_car_data.wheelbase = used_car_data.wheelbase.replace('--', float('nan'))
used_car_data.wheelbase.str.endswith(' in').all()
# Out:
# True

# %%
used_car_data.wheelbase = used_car_data.wheelbase.str.replace(' in', '').astype('float')

# %%
used_car_data.body_type.hasnans
# Out:
# False

# %%
#le_bed = preprocessing.LabelEncoder()
#le_bed.fit(used_car_data.bed)
#le_bed.classes_

# %%
#used_car_data.bed = le_bed.transform(used_car_data.bed)

# %%
enc_map = {}
def trf_cat(feat):
    le = preprocessing.LabelEncoder()
    le.fit(used_car_data[feat])
    print(le.classes_)
    #print('Good?')
    if True: #input() == 'y':
        used_car_data[feat] = le.transform(used_car_data[feat])
        enc_map[feat] = le
        # print('Done')

# %%
trf_cat('bed')
# Out:
# ['Long' 'Regular' 'Short' None]

# %%
trf_cat('body_type')
# Out:
# ['Convertible' 'Coupe' 'Hatchback' 'Minivan' 'Pickup Truck'
#  'SUV / Crossover' 'Sedan' 'Van' 'Wagon']

# %%
trf_cat('cabin')
# Out:
# ['Crew Cab' 'Extended Cab' 'Large Crew Cab' 'Regular Cab' None]

# %%
trf_cat('city')
# Out:
# ['Albuquerque' 'Alexandria' 'Arlington' 'Atlanta' 'Austin' 'Bakersfield'
#  'Baltimore' 'Boston' 'Charlotte' 'Chicago' 'Colorado Springs' 'Columbus'
#  'Dallas' 'Denver' 'Detroit' 'El Paso' 'Fort Worth' 'Fresno' 'Houston'
#  'Indianapolis' 'Jacksonville' 'Kansas City' 'Las Vegas' 'Long Beach'
#  'Los Angeles' 'Louisville' 'Memphis' 'Mesa' 'Miami' 'Milwaukee'
#  'Minneapolis' 'Nashville' 'New York' 'Oakland' 'Oklahoma City' 'Omaha'
#  'Philadelphia' 'Phoenix' 'Portland' 'Raleigh' 'Sacramento' 'San Antonio'
#  'San Diego' 'San Francisco' 'San Jose' 'Seattle' 'Tucson' 'Tulsa'
#  'Virginia Beach' 'Wichita']

# %%
trf_cat('cylinder_config')
# Out:
# ['H' 'I' 'R' 'V' 'W']

# %%
trf_cat('common_make')
# Out:
# ['Acura' 'Alfa Romeo' 'Aston Martin' 'Audi' 'BMW' 'Bentley' 'Buick'
#  'Cadillac' 'Chevrolet' 'Chrysler' 'Dodge' 'FIAT' 'Ferrari' 'Ford' 'GMC'
#  'Genesis' 'Honda' 'Hummer' 'Hyundai' 'INFINITI' 'Jaguar' 'Jeep' 'Kia'
#  'Lamborghini' 'Land Rover' 'Lexus' 'Lincoln' 'MINI' 'Maserati' 'Mazda'
#  'McLaren' 'Mercedes-Benz' 'Mercury' 'Mitsubishi' 'Nissan' 'Oldsmobile'
#  'Pontiac' 'Porsche' 'RAM' 'Rolls-Royce' 'Saab' 'Saturn' 'Scion' 'Subaru'
#  'Suzuki' 'Tesla' 'Toyota' 'Volkswagen' 'Volvo' 'smart' nan]

# %%
used_car_data.fuel_type = used_car_data.fuel_type.fillna('Gasoline')

# %%
trf_cat('fuel_type')
# Out:
# ['Biodiesel' 'Compressed Natural Gas' 'Diesel' 'Electric'
#  'Flex Fuel Vehicle' 'Gasoline' 'Hybrid' 'Propane']

# %%
trf_cat('listing_color')
# Out:
# ['BLACK' 'BLUE' 'BROWN' 'GOLD' 'GRAY' 'GREEN' 'ORANGE' 'PINK' 'PURPLE'
#  'RED' 'SILVER' 'TEAL' 'UNKNOWN' 'WHITE' 'YELLOW']

# %%
used_car_data.transmission = used_car_data.transmission.fillna('A')

# %%
trf_cat('transmission')
# Out:
# ['A' 'CVT' 'Dual Clutch' 'M']

# %%
used_car_data.wheel_system = used_car_data.wheel_system.fillna('FWD')

# %%
used_car_data.cabin.value_counts()
# Out:
# 4    2936507
# 0      51083
# 1       7960
# 3       2966
# 2       1524
# Name: cabin, dtype: int64

# %%
sum(used_car_data.mileage.isna())
# Out:
# 144387

# %%
used_car_data.mileage.median()
# Out:
# 8267.0

# %%
used_car_data.mileage = used_car_data.mileage.fillna(10000)

# %%
processed_data = pd.DataFrame(used_car_data[
    ['price',
     'bed', 'body_type', 'cabin', 'city', 'common_make', 'fuel_type', 'listing_color', 'transmission',
     'cylinder_config', 'num_cylinders', 'rear_ctrl', 'front_ctrl',
     'fleet', 'frame_damaged', 'franchise_dealer', 'has_accidents', 'isCab', 'is_cpo', 'is_new', 'salvage',
     'back_legroom', 'bed_length', 'city_fuel_economy', 'daysonmarket', 'engine_displacement', 'front_legroom', 'fuel_tank_volume', 'height', 'highway_fuel_economy', 'horsepower', 'length', 'maximum_seating', 'mileage', 'owner_count', 'seller_rating', 'width', 'wheelbase']
])
processed_data['year_listed'] = year_listed
processed_data['month_listed'] = month_listed
processed_data['model_age'] = model_age
processed_data
# Out:
#            price  bed  body_type  cabin  city  common_make  fuel_type  \
# 0        23141.0    3          5      4    28           21          5
# 1        46500.0    3          5      4    28           24          5
# 2        46995.0    3          6      4    28           43          5
# 3        67430.0    3          5      4    28           24          5
# 4        48880.0    3          5      4    28           24          5
# ...          ...  ...        ...    ...   ...          ...        ...
# 3000035  17998.0    3          5      4    33            8          5
# 3000036  36490.0    3          5      4    33            8          5
# 3000037  12990.0    3          6      4    33           13          5
# 3000038  26998.0    3          6      4    33           20          2
# 3000039  19900.0    3          5      4    33           34          5
#
#          listing_color  transmission  cylinder_config  ...  length  \
# 0                   14             0                1  ...   166.6
# 1                    0             0                1  ...   181.0
# 2                   12             3                0  ...   180.9
# 3                    4             0                3  ...   195.1
# 4                    0             0                1  ...   181.0
# ...                ...           ...              ...  ...     ...
# 3000035             10             0                1  ...   183.1
# 3000036              0             0                3  ...   204.3
# 3000037              4             0                1  ...   191.7
# 3000038              5             0                1  ...   183.9
# 3000039             10             0                1  ...   184.5
#
#          maximum_seating  mileage  owner_count  seller_rating  width  \
# 0                    5.0      7.0          1.0       2.800000   79.6
# 1                    7.0      8.0          1.0       3.000000   85.6
# 2                    5.0  10000.0          3.0       4.000000   78.9
# 3                    7.0     11.0          1.0       3.000000   87.4
# 4                    7.0      7.0          1.0       3.000000   85.6
# ...                  ...      ...          ...            ...    ...
# 3000035              5.0  41897.0          1.0       4.272727   72.6
# 3000036              8.0      5.0          1.0       4.533333   78.6
# 3000037              5.0  57992.0          2.0       4.142857   83.5
# 3000038              5.0  27857.0          1.0       4.272727   81.7
# 3000039              7.0  22600.0          1.0       4.333333   72.4
#
#          wheelbase  year_listed  month_listed  model_age
# 0            101.2         2019             4          0
# 1            107.9         2020             2          0
# 2            104.3         2017             4          1
# 3            115.0         2020             2          0
# 4            107.9         2020             4          0
# ...            ...          ...           ...        ...
# 3000035      107.3         2020             8          2
# 3000036      120.9         2020             3          0
# 3000037      112.2         2020             6          4
# 3000038      111.6         2020             9          3
# 3000039      106.5         2020             8          3
#
# [3000040 rows x 41 columns]

# %%
enc_map['cabin'].transform(['Crew Cab'])
# Out:
# array([0])

# %%
processed_data.salvage = processed_data.salvage.fillna(False)

# %%
med_bleg_by_body = processed_data.groupby('body_type').back_legroom.median()
na_bleg = processed_data.back_legroom.isna()
processed_data.loc[na_bleg, 'back_legroom'] = med_bleg_by_body[processed_data[na_bleg].body_type].values

# %%
# nan means no bed
processed_data.bed_length = processed_data.bed_length.fillna(0.)

# %%
med_cfe_by_body = processed_data.groupby('body_type').city_fuel_economy.median()
na_cfe = processed_data.city_fuel_economy.isna()
processed_data.loc[na_cfe, 'city_fuel_economy'] = med_cfe_by_body[processed_data[na_cfe].body_type].values

# %%
med_ed_by_body = processed_data.groupby('body_type').engine_displacement.median()
na_ed = processed_data.engine_displacement.isna()
processed_data.loc[na_ed, 'engine_displacement'] = med_ed_by_body[processed_data[na_ed].body_type].values

# %%
med_fl_by_body = processed_data.groupby('body_type').front_legroom.median()
na_fl = processed_data.front_legroom.isna()
processed_data.loc[na_fl, 'front_legroom'] = med_fl_by_body[processed_data[na_fl].body_type].values

# %%
med_fv_by_body = processed_data.groupby('body_type').fuel_tank_volume.median()
na_fv = processed_data.fuel_tank_volume.isna()
processed_data.loc[na_fv, 'fuel_tank_volume'] = med_fv_by_body[processed_data[na_fv].body_type].values

# %%
med_height_by_body = processed_data.groupby('body_type').height.median()
na_height = processed_data.height.isna()
processed_data.loc[na_height, 'height'] = med_height_by_body[processed_data[na_height].body_type].values

# %%
med_hfe_by_body = processed_data.groupby('body_type').highway_fuel_economy.median()
na_hfe = processed_data.highway_fuel_economy.isna()
processed_data.loc[na_hfe, 'highway_fuel_economy'] = med_hfe_by_body[processed_data[na_hfe].body_type].values

# %%
med_hp_by_body = processed_data.groupby('body_type').horsepower.median()
na_hp = processed_data.horsepower.isna()
processed_data.loc[na_hp, 'horsepower'] = med_hp_by_body[processed_data[na_hp].body_type].values

# %%
med_length_by_body = processed_data.groupby('body_type').length.median()
na_length = processed_data.length.isna()
processed_data.loc[na_length, 'length'] = med_length_by_body[processed_data[na_length].body_type].values

# %%
med_ms_by_body = processed_data.groupby('body_type').maximum_seating.median()
na_ms = processed_data.maximum_seating.isna()
processed_data.loc[na_ms, 'maximum_seating'] = med_ms_by_body[processed_data[na_ms].body_type].values

# %%
med_width_by_body = processed_data.groupby('body_type').width.median()
na_width = processed_data.width.isna()
processed_data.loc[na_width, 'width'] = med_width_by_body[processed_data[na_width].body_type].values

# %%
processed_data.groupby('body_type').wheelbase.std()
# Out:
# body_type
# 0     6.685326
# 1     5.310521
# 2     4.712866
# 3     1.757404
# 4    10.313188
# 5     6.506079
# 6     4.406548
# 7    15.091283
# 8     4.403115
# Name: wheelbase, dtype: float64

# %%
med_wb_by_body = processed_data.groupby('body_type').wheelbase.median()
na_wb = processed_data.wheelbase.isna()
processed_data.loc[na_wb, 'wheelbase'] = med_wb_by_body[processed_data[na_wb].body_type].values

# %%
[k for k in processed_data if processed_data[k].hasnans]
# Out:
# []

# %%
processed_data.to_parquet("processed_ucd_2.parquet", compression=None)

# %%
def ask_data(col):
    if col in enc_map:
        print(f'Input {col}')
        print(f'    Options: {enc_map[col].classes_}')
        return enc_map[col].transform([input('    Take a pick:')])[0]
    else:
        return float(input(f'Input {col}:'))

def ask_column(cols):
    return list(map(ask_data, cols))

# %%
processed_data.groupby('city').price.median().sort_values()
# Out:
# city
# 46    22294.00
# 25    23966.00
# 48    24000.00
# 17    24250.00
# 19    24825.00
# 37    25135.50
# 49    25253.00
# 21    25415.00
# 20    25589.00
# 31    25615.50
# 28    25638.00
# 39    25695.00
# 23    25781.00
# 11    25800.00
# 9     25839.00
# 22    25900.00
# 47    25977.00
# 3     25995.00
# 1     26048.00
# 27    26076.00
# 29    26082.00
# 26    26161.00
# 8     26500.00
# 30    26610.50
# 36    26720.00
# 40    26737.00
# 34    26774.00
# 6     26788.00
# 4     26800.00
# 42    26888.00
# 10    26900.00
# 0     26964.00
# 2     26974.00
# 38    26990.00
# 35    26995.00
# 12    27064.00
# 7     27190.00
# 45    27356.50
# 24    27449.00
# 14    27474.33
# 41    27535.00
# 13    27670.00
# 5     27785.00
# 44    27850.00
# 32    27877.50
# 18    28195.00
# 15    28320.00
# 33    28486.00
# 43    29445.00
# 16    29721.00
# Name: price, dtype: float64

# %%
enc_map['city'].inverse_transform([17])
# Out:
# array(['Fresno'], dtype=object)

# %%
ppd_corr = processed_data.corr()

# %%
ppd_corr.style.background_gradient(cmap='coolwarm').format(precision=2).hide(axis="columns")
# Out:
# <style type="text/css">
# #T_736c1_row0_col0, #T_736c1_row1_col1, #T_736c1_row2_col2, #T_736c1_row3_col3, #T_736c1_row4_col4, #T_736c1_row5_col5, #T_736c1_row6_col6, #T_736c1_row7_col7, #T_736c1_row8_col8, #T_736c1_row9_col9, #T_736c1_row10_col10, #T_736c1_row11_col11, #T_736c1_row12_col12, #T_736c1_row13_col13, #T_736c1_row14_col14, #T_736c1_row15_col15, #T_736c1_row16_col16, #T_736c1_row17_col17, #T_736c1_row18_col18, #T_736c1_row19_col19, #T_736c1_row20_col20, #T_736c1_row21_col21, #T_736c1_row22_col22, #T_736c1_row23_col23, #T_736c1_row24_col24, #T_736c1_row25_col25, #T_736c1_row26_col26, #T_736c1_row27_col27, #T_736c1_row28_col28, #T_736c1_row29_col29, #T_736c1_row30_col30, #T_736c1_row31_col31, #T_736c1_row32_col32, #T_736c1_row33_col33, #T_736c1_row34_col34, #T_736c1_row35_col35, #T_736c1_row36_col36, #T_736c1_row37_col37, #T_736c1_row38_col38, #T_736c1_row39_col39, #T_736c1_row40_col40 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col1, #T_736c1_row0_col5, #T_736c1_row5_col21, #T_736c1_row6_col25, #T_736c1_row16_col15, #T_736c1_row22_col23, #T_736c1_row37_col18, #T_736c1_row40_col20 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col2, #T_736c1_row4_col20, #T_736c1_row8_col14, #T_736c1_row8_col20, #T_736c1_row15_col17, #T_736c1_row23_col14, #T_736c1_row26_col14, #T_736c1_row28_col7, #T_736c1_row37_col5 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col3, #T_736c1_row2_col8, #T_736c1_row4_col5, #T_736c1_row8_col18, #T_736c1_row12_col18, #T_736c1_row12_col25, #T_736c1_row19_col32, #T_736c1_row23_col18, #T_736c1_row24_col8, #T_736c1_row24_col16, #T_736c1_row26_col32, #T_736c1_row30_col17, #T_736c1_row33_col8, #T_736c1_row36_col26, #T_736c1_row37_col17, #T_736c1_row38_col21 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col4, #T_736c1_row1_col35, #T_736c1_row5_col26, #T_736c1_row6_col22, #T_736c1_row9_col29, #T_736c1_row18_col4, #T_736c1_row18_col7, #T_736c1_row20_col4, #T_736c1_row22_col2, #T_736c1_row34_col4, #T_736c1_row40_col4 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col6, #T_736c1_row2_col11, #T_736c1_row2_col37, #T_736c1_row8_col9, #T_736c1_row11_col16, #T_736c1_row17_col8, #T_736c1_row22_col16, #T_736c1_row23_col16, #T_736c1_row23_col39, #T_736c1_row24_col32, #T_736c1_row26_col18, #T_736c1_row30_col16, #T_736c1_row32_col18, #T_736c1_row32_col23, #T_736c1_row33_col3, #T_736c1_row33_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col7, #T_736c1_row19_col26, #T_736c1_row23_col37, #T_736c1_row25_col3, #T_736c1_row25_col8, #T_736c1_row33_col35 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col8, #T_736c1_row17_col14, #T_736c1_row20_col1, #T_736c1_row24_col1, #T_736c1_row24_col20, #T_736c1_row28_col5, #T_736c1_row34_col19, #T_736c1_row35_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col9, #T_736c1_row19_col24 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_736c1_row0_col10, #T_736c1_row21_col30 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_736c1_row0_col11, #T_736c1_row11_col36, #T_736c1_row32_col10 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_736c1_row0_col12, #T_736c1_row8_col1, #T_736c1_row18_col1, #T_736c1_row21_col1, #T_736c1_row40_col12 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col13, #T_736c1_row0_col17, #T_736c1_row2_col0, #T_736c1_row3_col37, #T_736c1_row12_col11, #T_736c1_row13_col1, #T_736c1_row31_col2, #T_736c1_row39_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col14, #T_736c1_row0_col20, #T_736c1_row3_col26, #T_736c1_row10_col8, #T_736c1_row18_col35, #T_736c1_row21_col7, #T_736c1_row23_col26, #T_736c1_row23_col27, #T_736c1_row28_col26, #T_736c1_row34_col0, #T_736c1_row34_col26, #T_736c1_row34_col35, #T_736c1_row40_col26 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col15 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_736c1_row0_col16, #T_736c1_row2_col22, #T_736c1_row10_col35, #T_736c1_row22_col7, #T_736c1_row36_col1, #T_736c1_row37_col29 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col18, #T_736c1_row2_col36, #T_736c1_row3_col32, #T_736c1_row7_col18, #T_736c1_row9_col6, #T_736c1_row12_col31, #T_736c1_row12_col36, #T_736c1_row16_col18, #T_736c1_row19_col5, #T_736c1_row33_col18, #T_736c1_row34_col20, #T_736c1_row34_col32 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col19 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_736c1_row0_col21, #T_736c1_row8_col40, #T_736c1_row15_col23, #T_736c1_row16_col10, #T_736c1_row16_col25, #T_736c1_row19_col37, #T_736c1_row20_col29, #T_736c1_row24_col29, #T_736c1_row29_col19, #T_736c1_row36_col15 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_736c1_row0_col22, #T_736c1_row6_col29, #T_736c1_row16_col24, #T_736c1_row21_col11, #T_736c1_row22_col24, #T_736c1_row25_col40, #T_736c1_row32_col24, #T_736c1_row36_col38, #T_736c1_row37_col32 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_736c1_row0_col23, #T_736c1_row0_col39, #T_736c1_row1_col32, #T_736c1_row5_col0, #T_736c1_row6_col16, #T_736c1_row6_col18, #T_736c1_row7_col32, #T_736c1_row12_col39, #T_736c1_row13_col22, #T_736c1_row14_col0, #T_736c1_row17_col12, #T_736c1_row17_col18, #T_736c1_row19_col8, #T_736c1_row21_col17, #T_736c1_row21_col23, #T_736c1_row21_col33, #T_736c1_row23_col33, #T_736c1_row26_col21, #T_736c1_row27_col16, #T_736c1_row27_col17, #T_736c1_row29_col34, #T_736c1_row30_col13, #T_736c1_row35_col32, #T_736c1_row37_col13, #T_736c1_row38_col0, #T_736c1_row38_col5 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col24, #T_736c1_row10_col32 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_736c1_row0_col25, #T_736c1_row31_col11, #T_736c1_row36_col22 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_736c1_row0_col26, #T_736c1_row5_col1, #T_736c1_row6_col0, #T_736c1_row9_col26, #T_736c1_row17_col19, #T_736c1_row21_col5, #T_736c1_row22_col5, #T_736c1_row26_col5, #T_736c1_row28_col2, #T_736c1_row28_col18 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col27, #T_736c1_row22_col9, #T_736c1_row22_col36 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_736c1_row0_col28, #T_736c1_row9_col22, #T_736c1_row21_col36 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_736c1_row0_col29, #T_736c1_row1_col5, #T_736c1_row2_col32, #T_736c1_row3_col25, #T_736c1_row4_col32, #T_736c1_row8_col30, #T_736c1_row13_col18, #T_736c1_row16_col8, #T_736c1_row16_col20, #T_736c1_row17_col15, #T_736c1_row18_col16, #T_736c1_row18_col32, #T_736c1_row28_col13, #T_736c1_row35_col16 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col30 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_736c1_row0_col31, #T_736c1_row0_col36, #T_736c1_row0_col37, #T_736c1_row32_col30 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_736c1_row0_col32, #T_736c1_row1_col9, #T_736c1_row5_col28, #T_736c1_row6_col2, #T_736c1_row6_col8, #T_736c1_row9_col19, #T_736c1_row13_col31, #T_736c1_row14_col16, #T_736c1_row14_col19, #T_736c1_row15_col3, #T_736c1_row17_col31, #T_736c1_row19_col9, #T_736c1_row27_col15, #T_736c1_row35_col0, #T_736c1_row39_col23, #T_736c1_row39_col33, #T_736c1_row39_col36, #T_736c1_row40_col28, #T_736c1_row40_col29, #T_736c1_row40_col31 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_736c1_row0_col33, #T_736c1_row1_col20, #T_736c1_row8_col32, #T_736c1_row11_col2, #T_736c1_row11_col14, #T_736c1_row14_col26, #T_736c1_row15_col13, #T_736c1_row18_col20, #T_736c1_row30_col14, #T_736c1_row30_col20, #T_736c1_row31_col20, #T_736c1_row36_col12, #T_736c1_row37_col20 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_736c1_row0_col34, #T_736c1_row1_col26, #T_736c1_row4_col26, #T_736c1_row15_col7, #T_736c1_row16_col26, #T_736c1_row21_col20, #T_736c1_row27_col35, #T_736c1_row28_col6, #T_736c1_row28_col14, #T_736c1_row28_col20, #T_736c1_row29_col26, #T_736c1_row36_col7 {
#   background-color: #536edd;
#   color: #f1f1f

# %%
ppd_corr.price.abs().sort_values(ascending=False)
# Out:
# price                   1.000000
# horsepower              0.567266
# is_new                  0.378275
# rear_ctrl               0.376462
# fuel_tank_volume        0.375563
# width                   0.369239
# model_age               0.358916
# length                  0.356081
# wheelbase               0.354062
# engine_displacement     0.352521
# num_cylinders           0.334364
# height                  0.294759
# cylinder_config         0.292794
# franchise_dealer        0.282265
# owner_count             0.281391
# mileage                 0.271031
# highway_fuel_economy    0.257575
# bed_length              0.225028
# back_legroom            0.224200
# has_accidents           0.197793
# city_fuel_economy       0.186369
# body_type               0.176794
# fleet                   0.168321
# fuel_type               0.146617
# isCab                   0.138605
# transmission            0.125201
# maximum_seating         0.122047
# front_ctrl              0.104542
# front_legroom           0.075267
# seller_rating           0.068455
# daysonmarket            0.063288
# frame_damaged           0.055880
# common_make             0.054026
# year_listed             0.052042
# salvage                 0.049096
# cabin                   0.041931
# bed                     0.027103
# listing_color           0.021469
# month_listed            0.018961
# is_cpo                  0.011928
# city                    0.007979
# Name: price, dtype: float64

# %%
import pickle
with open('enc_map.pickle', 'wb') as f:
    pickle.dump(enc_map, f)

# %%
[c for c in processed_data.columns if processed_data[c].hasnans]
# Out:
# []

# %%
len(used_car_data.columns)
