# %%
import numpy as np
import pandas as pd

from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.feature_selection import mutual_info_regression
from sklearn.model_selection import train_test_split

# %%
ucd = pd.read_parquet('processed_ucd.parquet')

# %%
X = ucd[ucd.columns[1:]]
y = ucd.price

# %%
categ = X.columns.map(lambda x: x in {'bed', 'body_type', 'cabin', 'city', 'engine_cylinders', 'franchise_make', 'fuel_type', 'listing_color', 'transmission', 'wheel_system'})
boolean = X.columns.map(lambda x: x in {'fleet', 'frame_damaged', 'franchise_dealer', 'has_accidents', 'isCab', 'is_cpo', 'is_new', 'salvage'})
integer = X.columns.map(lambda x: x in {'year_listed', 'month_listed', 'owner_count', 'maximum_seating'})

# %%
sfs = SequentialFeatureSelector(HistGradientBoostingRegressor(), n_features_to_select='auto', tol=None, n_jobs=-1)

# %%
X_sfs, __, y_sfs, __ = train_test_split(X, y, train_size=0.05)
del __
X_sfs[X_sfs.columns[~categ]]
# Out:
#          fleet  frame_damaged  franchise_dealer  has_accidents  isCab  is_cpo  \
# 1898903  False          False              True          False  False   False
# 1222743  False          False             False          False  False   False
# 1579978  False          False              True          False  False    True
# 462791   False          False              True          False  False    True
# 150589   False          False              True          False  False   False
# ...        ...            ...               ...            ...    ...     ...
# 1847556  False          False              True          False  False    True
# 299187   False          False              True          False  False   False
# 48870    False          False             False          False  False   False
# 1367312  False          False             False           True  False   False
# 1874316  False          False              True          False  False   False
#
#          is_new  salvage  back_legroom  bed_length  ...  length  \
# 1898903   False    False          38.6         NaN  ...   201.2
# 1222743   False    False          32.9         NaN  ...   189.9
# 1579978   False    False          38.2         NaN  ...   176.4
# 462791    False    False          40.3        67.4  ...   229.0
# 150589     True    False          40.7         NaN  ...   180.5
# ...         ...      ...           ...         ...  ...     ...
# 1847556   False    False          39.5         NaN  ...   189.5
# 299187     True    False           NaN         NaN  ...     NaN
# 48870     False    False          40.9        69.3  ...   230.0
# 1367312   False    False          36.3         NaN  ...   178.7
# 1874316    True    False          38.0         NaN  ...   192.7
#
#          maximum_seating   mileage  owner_count  seller_rating  width  \
# 1898903              7.0   29738.0          1.0       3.666667   85.5
# 1222743              7.0  180000.0          1.0       4.000000   75.8
# 1579978              5.0   32686.0          1.0       4.263158   73.0
# 462791               6.0   24981.0          1.0       3.333333   79.4
# 150589               5.0       5.0          1.0       4.500000   85.6
# ...                  ...       ...          ...            ...    ...
# 1847556              5.0   39971.0          1.0       4.000000   75.0
# 299187               NaN   10000.0          1.0       4.692308    NaN
# 48870                6.0  101995.0          2.0       4.857143   80.0
# 1367312              5.0  197250.0          2.0       5.000000   69.3
# 1874316              5.0       5.0          1.0       4.514286   72.4
#
#          wheelbase  year_listed  month_listed  model_age
# 1898903      119.8         2020             9          1
# 1222743      109.8         2020             8          7
# 1579978      105.1         2020             8          2
# 462791       140.5         2020             7          3
# 150589       106.7         2020             7          0
# ...            ...          ...           ...        ...
# 1847556      112.5         2020             8          3
# 299187         NaN         2020             8         -1
# 48870        143.5         2020             6          6
# 1367312      102.4         2019             7         10
# 1874316      111.2         2020             8          0
#
# [150002 rows x 28 columns]

# %%
sfs_non_cat = sfs.fit(X_sfs[X_sfs.columns[~categ]], y_sfs)

# %%
sfs_non_cat.get_feature_names_out()
# Out:
# array(['fleet', 'back_legroom', 'bed_length', 'city_fuel_economy',
#        'engine_displacement', 'fuel_tank_volume', 'height', 'horsepower',
#        'maximum_seating', 'mileage', 'width', 'wheelbase', 'year_listed',
#        'model_age'], dtype=object)

# %%
# IDK what fleet means, so we'll take 
# 'back_legroom', 'bed_length', 'city_fuel_economy', 'engine_displacement', 
# 'fuel_tank_volume', 'height', 'horsepower', 'maximum_seating', 'mileage', 
# 'width', 'wheelbase', 'year_listed','model_age'

# %%
X_sfs[X_sfs.columns[categ]]
# Out:
#          bed  body_type  cabin  city  engine_cylinders  franchise_make  \
# 1898903    3          5      4    57                10              10
# 1222743    3          5      4    30                 9              48
# 1579978    3          5      4    28                 4              22
# 462791     3          4      4    51                10              37
# 150589     3          5      4    51                 4              13
# ...      ...        ...    ...   ...               ...             ...
# 1847556    3          5      4    50                 9               7
# 299187     3          4      4    51                 4              37
# 48870      3          4      4    51                 9              48
# 1367312    3          6      4    83                 4              48
# 1874316    3          6      4    57                 4              44
#
#          fuel_type  listing_color  transmission  wheel_system
# 1898903          5              4             0             2
# 1222743          5             13             0             1
# 1579978          5             13             0             3
# 462791           5             13             0             0
# 150589           5             10             0             2
# ...            ...            ...           ...           ...
# 1847556          5              0             0             0
# 299187           5             13             0             3
# 48870            4             13             0             0
# 1367312          5             12             0             3
# 1874316          5             11             0             3
#
# [150002 rows x 10 columns]

# %%
mi = mutual_info_regression(X[X.columns[categ]], y, discrete_features=[True for _ in X.columns[categ]])
mi
# Out:
# array([0.00532119, 0.25691869, 0.01328851, 0.33934268, 0.24108075,
#        0.61537409, 0.06943575, 0.05704944, 0.0962967 , 0.22728871])

# %%
pd.Series(mi, index=X.columns[categ]).sort_values()
# Out:
# bed                 0.005321
# cabin               0.013289
# listing_color       0.057049
# fuel_type           0.069436
# transmission        0.096297
# wheel_system        0.227289
# engine_cylinders    0.241081
# body_type           0.256919
# city                0.339343
# franchise_make      0.615374
# dtype: float64

# %%
# We'll take 'franchise_make', 'city', 'body_type', 'engine_cylinders', 'wheel_system'

# %%
# Ok, so in total we have:
# 'franchise_make', 'city', 'body_type', 'engine_cylinders', 'wheel_system',
# 'back_legroom', 'bed_length', 'city_fuel_economy', 'engine_displacement', 
# 'fuel_tank_volume', 'height', 'horsepower', 'maximum_seating', 'mileage', 
# 'width', 'wheelbase', 'year_listed', 'model_age'
# 
# But that seems like maybe a bit too many features.
# I can't be bothered to cut it down though, let's just get rollin!

# %%
X_best = X[['franchise_make', 'city', 'body_type', 'engine_cylinders', 'wheel_system',
            'back_legroom', 'bed_length', 'city_fuel_economy', 'engine_displacement', 
            'fuel_tank_volume', 'height', 'horsepower', 'maximum_seating', 'mileage', 
            'width', 'wheelbase', 'year_listed','model_age']]

categ_best = X_best.columns.map(lambda x: x in {'bed', 'body_type', 'cabin', 'city', 'engine_cylinders', 'franchise_make', 'fuel_type', 'listing_color', 'transmission', 'wheel_system'})

# %%
Xb_train, Xb_test, y_train, y_test = train_test_split(X_best, y, train_size=0.3)
Xb_train
# Out:
#          franchise_make  city  body_type  engine_cylinders  wheel_system  \
# 675527               48     9          6                 9             3
# 1568816              28    28          5                 4             3
# 1841345               7    39          6                 4             2
# 1541479              48    27          6                 4             3
# 1522418              13    55          4                 9             0
# ...                 ...   ...        ...               ...           ...
# 2150163               9    53          3                 9             3
# 1000107              34    20          5                 9             2
# 2437480              48     2          6                 4             3
# 2531407              44     2          4                10             0
# 1347413              48    61          3                 9             3
#
#          back_legroom  bed_length  city_fuel_economy  engine_displacement  \
# 675527           36.2         NaN               19.0               3600.0
# 1568816          37.9         NaN               26.0               2500.0
# 1841345          37.9         NaN               21.0               2000.0
# 1541479          39.1         NaN               23.0               1800.0
# 1522418          33.5        78.9               18.0               3300.0
# ...               ...         ...                ...                  ...
# 2150163          39.0         NaN               19.0               3600.0
# 1000107          38.7         NaN               20.0               3500.0
# 2437480          35.4         NaN                NaN               1800.0
# 2531407          34.7        78.7               13.0               5700.0
# 1347413          39.6         NaN                NaN               3500.0
#
#          fuel_tank_volume  height  horsepower  maximum_seating   mileage  \
# 675527               16.9    58.4       283.0              5.0  132632.0
# 1568816              14.5    68.1       170.0              5.0   27630.0
# 1841345              17.4    57.2       237.0              5.0     979.0
# 1541479              18.5    58.5       170.0              5.0   27784.0
# 1522418              23.0    77.2       290.0              6.0       5.0
# ...                   ...     ...         ...              ...       ...
# 2150163              19.0    69.9       287.0              8.0       0.0
# 1000107              19.0    67.8       260.0              5.0       3.0
# 2437480              15.6    58.1       136.0              5.0  112109.0
# 2531407              26.4    76.4       381.0              6.0       5.0
# 1347413              20.0    68.9       266.0              7.0  242784.0
#
#          width  wheelbase  year_listed  model_age
# 675527    81.3      108.9         2020          7
# 1568816   72.4      106.5         2020          3
# 1841345   80.3      116.0         2020          0
# 1541479   72.2      110.4         2020          3
# 1522418   96.8      145.0         2019          0
# ...        ...        ...          ...        ...
# 2150163   90.4      121.6         2020          0
# 1000107   75.4      111.2         2020          0
# 2437480   70.7      105.7         2020          9
# 2531407   79.9      145.7         2020          0
# 1347413   77.4      119.3         2020         11
#
# [900012 rows x 18 columns]

# %%
hgbr = HistGradientBoostingRegressor(categorical_features=categ_best, early_stopping=False, max_iter=250, max_leaf_nodes=400, learning_rate=0.07)

# %%
hgbr.fit(Xb_train, y_train)
hgbr.score(Xb_test, y_test)
# Out:
# 0.8501212565255537

# %%
example = pd.DataFrame([[23, 48, 0, 10, 2, 40, float('nan'), 20, 2000, 30, 60, 400, 6, 0, 80, 100, 2022, 0]], columns=X_best.columns)
example
# Out:
#    franchise_make  city  body_type  engine_cylinders  wheel_system  \
# 0              23    48          0                10             2
#
#    back_legroom  bed_length  city_fuel_economy  engine_displacement  \
# 0            40         NaN                 20                 2000
#
#    fuel_tank_volume  height  horsepower  maximum_seating  mileage  width  \
# 0                30      60         400                6        0     80
#
#    wheelbase  year_listed  model_age
# 0        100         2022          0

# %%
predictions = hgbr.predict(example)
# Out:
# array([128509.45186946])

# %%
from sklearn.metrics import classification_report,confusion_matrix
print(confusion_matrix(y_test,predictions))
print(classification_report(y_test,predictions))
